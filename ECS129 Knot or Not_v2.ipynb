# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import time

# %%
dataVals = np.genfromtxt(r'1zncA.txt', delimiter='', dtype=float)
avgCoords = []
indexofthresholds = []
x = 0

# %%
def ray_dir(E,F):
    d = E-F

# %%
def intersect_line_triangle(q1, q2, p1, p2, p3):
    def signed_tetra_volume(a, b, c, d):
        return np.sign(np.dot(np.cross(b - a, c - a), d - a) / 6.0)

    numknots = 0
    s1 = signed_tetra_volume(p1, p2, p3, q1)
    s2 = signed_tetra_volume(p1, p2, p3, q2)

    if s1 != s2:
        s3 = signed_tetra_volume(p1, p2, q1, q2)
        s4 = signed_tetra_volume(p2, p3, q1, q2)
        s5 = signed_tetra_volume(p3, p1, q1, q2)
        if s3==s4 and s4==s5:
#            n = np.cross(p2 - p1, p3 - p1)
#            t = np.dot(p1 - q1, n) / np.dot(q2 - q1, n)
            numknots = numknots + 1
    # return None
    return numknots

# %% [markdown]
# # Strategy 1: Once threshold is reach, remove the point

# %%
def lineseg_dist(p, a, b):

    # normalized tangent vector
    d = np.divide(b - a, np.linalg.norm(b - a))

    # signed parallel distance components
    s = np.dot(a - p, d)
    t = np.dot(p - b, d)

    # clamped parallel distance
    h = np.maximum.reduce([s, t, 0])

    # perpendicular distance component
    c = np.cross(p - a, d)

    return np.hypot(h, np.linalg.norm(c))

# %% [markdown]
# # Run Code

# %%
totalTime = 0
for k in range(0, 50):
    nproblem = 0
    start = time.time()

    for i in range(0, len(dataVals) - 2):

        xCoord = (dataVals[i][0] + dataVals[i + 1][0] + dataVals[i + 2][0]) / 3
        yCoord = (dataVals[i][1] + dataVals[i + 1][1] + dataVals[i + 2][1]) / 3
        zCoord = (dataVals[i][2] + dataVals[i + 1][2] + dataVals[i + 2][2]) / 3
        
        avgCoords=[xCoord, yCoord, zCoord];
        
        A = dataVals[i]
        B = dataVals[i + 1]
        C = avgCoords

        nk=0

        for j in range(0, i-2): 
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        for j in range(i + 2, len(dataVals)-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        A = dataVals[i + 1]
        B = avgCoords
        C = dataVals[i + 2]

        for j in range(0, i-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        for j in range(i + 3, len(dataVals)-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)
        
        if nk==0:
            dataVals[i + 1] = avgCoords
        nproblem += nk
        
        # Check if distance is short enough
        distance = lineseg_dist(avgCoords, dataVals[i], dataVals[i+2])
        if distance < 0.01:
            indexofthresholds.append(i)
            print(i)
            
    for i in indexofthresholds:
        dataVals = np.delete(dataVals, i, 0)
    indexofthresholds = []
    end = time.time()
    
    print("On iteration:", k)
    totalTime += round(end - start, 10)
    print("Time for execution of program: {}".format(round(end-start, 10)))

    print("curr possible numknot:", nproblem)
print("Total program runtime: {}".format(totalTime))
# Out:
# On iteration: 0
# Time for execution of program: 10.1521940231
# curr possible numknot: 0
# 92
# On iteration: 1
# Time for execution of program: 9.9411141872
# curr possible numknot: 0
# On iteration: 2
# Time for execution of program: 9.864792347
# curr possible numknot: 0
# On iteration: 3
# Time for execution of program: 9.7723248005
# curr possible numknot: 0
# On iteration: 4
# Time for execution of program: 9.870465517
# curr possible numknot: 0
# 225
# On iteration: 5
# Time for execution of program: 9.8933360577
# curr possible numknot: 0
# On iteration: 6
# Time for execution of program: 9.7945957184
# curr possible numknot: 0
# 13
# On iteration: 7
# Time for execution of program: 9.7983772755
# curr possible numknot: 0
# 134
# On iteration: 8
# Time for execution of program: 9.6056220531
# curr possible numknot: 0
# 133
# 227
# On iteration: 9
# Time for execution of program: 9.6274354458
# curr possible numknot: 0
# 178
# On iteration: 10
# Time for execution of program: 9.3754417896
# curr possible numknot: 0
# 66
# On iteration: 11
# Time for execution of program: 9.3939445019
# curr possible numknot: 0
# On iteration: 12
# Time for execution of program: 9.2534821033
# curr possible numknot: 1
# On iteration: 13
# Time for execution of program: 9.3064823151
# curr possible numknot: 1
# On iteration: 14
# Time for execution of program: 9.2849669456
# curr possible numknot: 1
# 132
# On iteration: 15
# Time for execution of program: 9.3547914028
# curr possible numknot: 1
# On iteration: 16
# Time for execution of program: 9.2692141533
# curr possible numknot: 2
# 136
# On iteration: 17
# Time for execution of program: 9.2033367157
# curr possible numknot: 4
# On iteration: 18
# Time for execution of program: 9.1814820766
# curr possible numknot: 4
# 132
# 136
# 138
# On iteration: 19
# Time for execution of program: 9.1391708851
# curr possible numknot: 4
# 26
# 27
# On iteration: 20
# Time for execution of program: 8.8609161377
# curr possible numknot: 0
# 129
# 132
# On iteration: 21
# Time for execution of program: 8.7938091755
# curr possible numknot: 0
# 129
# On iteration: 22
# Time for execution of program: 8.680128336
# curr possible numknot: 0
# 25
# 128
# On iteration: 23
# Time for execution of program: 8.6602253914
# curr possible numknot: 1
# On iteration: 24
# Time for execution of program: 8.3455629349
# curr possible numknot: 2
# On iteration: 25
# Time for execution of program: 8.5139560699
# curr possible numknot: 2
# 0
# On iteration: 26
# Time for execution of program: 8.3591585159
# curr possible numknot: 1
# On iteration: 27
# Time for execution of program: 8.3553514481
# curr possible numknot: 1
# On iteration: 28
# Time for execution of program: 8.3028583527
# curr possible numknot: 1
# 0
# On iteration: 29
# Time for execution of program: 8.294485569
# curr possible numknot: 1
# On iteration: 30
# Time for execution of program: 8.2079937458
# curr possible numknot: 1
# 0
# 237
# On iteration: 31
# Time for execution of program: 8.2941303253
# curr possible numknot: 1
# On iteration: 32
# Time for execution of program: 8.174033165
# curr possible numknot: 1
# On iteration: 33
# Time for execution of program: 8.1680366993
# curr possible numknot: 1
# 0
# On iteration: 34
# Time for execution of program: 8.0576725006
# curr possible numknot: 1
# 230
# On iteration: 35
# Time for execution of program: 8.0380675793
# curr possible numknot: 1
# On iteration: 36
# Time for execution of program: 8.0008947849
# curr possible numknot: 0
# 184
# On iteration: 37
# Time for execution of program: 8.0498769283
# curr possible numknot: 0
# On iteration: 38
# Time for execution of program: 7.9160604477
# curr possible numknot: 0
# On iteration: 39
# Time for execution of program: 7.8489553928
# curr possible numknot: 0
# 184
# On iteration: 40
# Time for execution of program: 7.8909723759
# curr possible numknot: 0
# 61
# On iteration: 41
# Time for execution of program: 7.8642911911
# curr possible numknot: 0
# 182
# On iteration: 42
# Time for execution of program: 7.7436730862
# curr possible numknot: 0
# 182
# On iteration: 43
# Time for execution of program: 7.6463685036
# curr possible numknot: 0
# 75
# On iteration: 44
# Time for execution of program: 7.6847667694
# curr possible numknot: 0
# 60
# 61
# 180
# 181
# On iteration: 45
# Time for execution of program: 7.6402425766
# curr possible numknot: 0
# On iteration: 46
# Time for execution of program: 7.4425663948
# curr possible numknot: 0
# 72
# 178
# On iteration: 47
# Time for execution of program: 7.410597086
# curr possible numknot: 0
# 95
