# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import time

# %% [markdown]
# # Optimization Trick: Check whether a line segment crosses the plane before checking for the triangle intersection

# %%
# helper functions to help us detect whether or not a line segment crosses a specified plane
def normal(p0,p1,p2):
    x0, y0, z0 = p0
    x1, y1, z1 = p1
    x2, y2, z2 = p2

    ux, uy, uz = u = [x1 - x0, y1 - y0, z1 - z0] #first vector
    vx, vy, vz = v = [x2 - x0, y2 - y0, z2 - z0] #sec vector

    u_cross_v = [uy * vz - uz * vy, uz * vx - ux * vz, ux * vy - uy * vx] #cross product

    point  = np.array(p1)
    normal = np.array(u_cross_v)
    return point, normal

def point_check(point, norm, p_plane):
    # In this instance we assume that the plane points 'up' and the arbitrary point
    # is below the plane
    dot_product = np.dot(norm, (point-p_plane))
    if dot_product <= 0: # point is below the plane
        return -1
    elif dot_product == 0: # point is on the plane
        return 0
    else:
        return 1 # point is above the plane

# This function verifies if the line segment crosses plane or not
def segment_verify(l1, l2, p1, p2, p3):
    plane_point, plane_norm = normal(p1, p2, p3)
    
    check1 = point_check(l1,plane_norm,plane_point)
    check2 = point_check(l2,plane_norm,plane_point)
    
    # If both checks return the same answer, that means line segment is not crossing the plane
    if check1 == check2:
        return False
    # If both checks return different answer that means line segment is crossing the plane
    else:
        return True

# %% [markdown]
# # Algorithm to Check for Knots

# %%
# determines if a line segments crosses the triangle
def intersect_line_triangle(q1, q2, p1, p2, p3):
    def signed_tetra_volume(a, b, c, d):
        return np.sign(np.dot(np.cross(b - a, c - a), d - a))

    numknots = 0
    val = segment_verify(q1, q2, p1, p2, p3)
    
    #If we know the line segment crosses the plane, check to see if it crosses the triangle in the plane to see if theres a knot
    if val == True:
        s3 = signed_tetra_volume(p1, p2, q1, q2)
        s4 = signed_tetra_volume(p2, p3, q1, q2)
        s5 = signed_tetra_volume(p3, p1, q1, q2)
        if s3==s4 and s4==s5:
            numknots = numknots + 1
    return numknots

# %% [markdown]
# # Optimization Trick: Once threshold is reach, remove the point

# %%
# Checking if Threshold is reached and we can skip and delete the index of i+1
def lineseg_dist(p, a, b):

    # normalized tangent vector
    d = np.divide(b - a, np.linalg.norm(b - a))

    # signed parallel distance components
    s = np.dot(a - p, d)
    t = np.dot(p - b, d)

    # clamped parallel distance
    h = np.maximum.reduce([s, t, 0])

    # perpendicular distance component
    c = np.cross(p - a, d)

    return np.hypot(h, np.linalg.norm(c))

# %% [markdown]
# # Run Code

# %%
# declaring necessary variables
avgCoords = []
indexofthresholds = []
filename = input("Enter in filename: ")
iterations = int(input("Enter in # of iterations: "))
dataVals = np.genfromtxt(filename, delimiter='', dtype=float)
totalKnotsFnd = 0
totalTime = 0

# Arbitrary # of iterations
for k in range(0, iterations):
    nproblem = 0
    start = time.time()
    
    for i in range(0, len(dataVals) - 2):
        # Attempting to straighten out the triangle
        xCoord = (dataVals[i][0] + dataVals[i + 1][0] + dataVals[i + 2][0]) / 3
        yCoord = (dataVals[i][1] + dataVals[i + 1][1] + dataVals[i + 2][1]) / 3
        zCoord = (dataVals[i][2] + dataVals[i + 1][2] + dataVals[i + 2][2]) / 3
        
        avgCoords=[xCoord, yCoord, zCoord];
        
        # Generating the triangle in 3d space to see if a line segment crosses it
        A = dataVals[i]
        B = dataVals[i + 1]
        C = avgCoords

        nk=0

        # Checking all line segments up until indexes used for the triangle
        # range is until i-2 since the line seg right before the i would never cross
        for j in range(0, i-2): 
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        # Checking all line segments after the indexes used for the triangle
        for j in range(i + 2, len(dataVals)-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        # Generating the other part of the triangle in 3d space to see if a line segment crosses it
        A = dataVals[i + 1]
        B = avgCoords
        C = dataVals[i + 2]

        # Checking all line segments up until indexes used for the triangle
        # range is until i-1 since the line seg right before the i would never cross
        for j in range(0, i-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)

        # Checking all line segments after the indexes used for the triangle
        for j in range(i + 3, len(dataVals)-1):
            E = dataVals[j]
            F = dataVals[j + 1]
            nk += intersect_line_triangle(E, F, A, B, C)
        
        # If no knots detected, we "pull" down the triangle at i+1 to the avgCoords to begin "straightening" the sequence
        if nk==0:
            dataVals[i + 1] = avgCoords
        nproblem += nk
        
        # Check if distance is short enough for Threshold trick
        distance = lineseg_dist(avgCoords, dataVals[i], dataVals[i+2])
        if distance < 0.01:
            indexofthresholds.append(i)
            
    # deletes the indexes that have reached the threshold since its in the middle of a straight line
    for i in indexofthresholds:
        dataVals = np.delete(dataVals, i, 0)
    indexofthresholds = []
    end = time.time()
    
    print("On iteration {}, {} knot(s) were detected with a time of {}".format(k, nproblem, round(end-start, 10)))
    totalKnotsFnd += nproblem
    totalTime += round(end - start, 10)

if totalKnotsFnd == 0:
    print("There were no knots found within the file")
print("Total program runtime: {}".format(totalTime))
# Out:
# Enter in filename: 1zncA.crd
# Enter in # of iterations: 50
# On iteration 0, 0 knot(s) were detected with a time of 2.1139991283
# On iteration 1, 0 knot(s) were detected with a time of 2.0450000763
# On iteration 2, 0 knot(s) were detected with a time of 2.0195188522
# On iteration 3, 0 knot(s) were detected with a time of 2.0671195984
# On iteration 4, 0 knot(s) were detected with a time of 2.0578877926
# On iteration 5, 0 knot(s) were detected with a time of 2.0550925732
# On iteration 6, 0 knot(s) were detected with a time of 2.0185501575
# On iteration 7, 0 knot(s) were detected with a time of 2.0060017109
# On iteration 8, 0 knot(s) were detected with a time of 1.9789974689
# On iteration 9, 0 knot(s) were detected with a time of 1.9620015621
# On iteration 10, 0 knot(s) were detected with a time of 1.9027833939
# On iteration 11, 0 knot(s) were detected with a time of 1.9080007076
# On iteration 12, 1 knot(s) were detected with a time of 1.8929998875
# On iteration 13, 1 knot(s) were detected with a time of 1.8761715889
# On iteration 14, 1 knot(s) were detected with a time of 1.8911836147
# On iteration 15, 1 knot(s) were detected with a time of 1.8648781776
# On iteration 16, 2 knot(s) were detected with a time of 1.8354227543
# On iteration 17, 4 knot(s) were detected with a time of 1.8426551819
# On iteration 18, 4 knot(s) were detected with a time of 1.8198251724
# On iteration 19, 4 knot(s) were detected with a time of 1.8500037193
# On iteration 20, 0 knot(s) were detected with a time of 1.778137207
# On iteration 21, 0 knot(s) were detected with a time of 1.7624650002
# On iteration 22, 0 knot(s) were detected with a time of 1.7220575809
# On iteration 23, 1 knot(s) were detected with a time of 1.7238788605
# On iteration 24, 2 knot(s) were detected with a time of 1.7090072632
# On iteration 25, 2 knot(s) were detected with a time of 1.685000658
# On iteration 26, 1 knot(s) were detected with a time of 1.7450008392
# On iteration 27, 1 knot(s) were detected with a time of 1.6855456829
# On iteration 28, 1 knot(s) were detected with a time of 1.6689991951
# On iteration 29, 1 knot(s) were detected with a time of 1.6679990292
# On iteration 30, 1 knot(s) were detected with a time of 1.6369974613
# On iteration 31, 1 knot(s) were detected with a time of 1.6430022717
# On iteration 32, 1 knot(s) were detected with a time of 1.6129996777
# On iteration 33, 1 knot(s) were detected with a time of 1.6210100651
# On iteration 34, 1 knot(s) were detected with a time of 1.6220021248
# On iteration 35, 1 knot(s) were detected with a time of 1.5970232487
# On iteration 36, 0 knot(s) were detected with a time of 1.5900123119
# On iteration 37, 0 knot(s) were detected with a time of 1.5760016441
# On iteration 38, 0 knot(s) were detected with a time of 1.5583221912
# On iteration 39, 0 knot(s) were detected with a time of 1.5623888969
# On iteration 40, 0 knot(s) were detected with a time of 1.5549993515
# On iteration 41, 0 knot(s) were detected with a time of 1.540997982
# On iteration 42, 0 knot(s) were detected with a time of 1.5270354748
# On iteration 43, 0 knot(s) were detected with a time of 1.519037962
# On iteration 44, 0 knot(s) were detected with a time of 1.4970009327
# On iteration 45, 0 knot(s) were detected with a time of 1.4919986725
# On iteration 46, 0 knot(s) were detected with a time of 1.4579956532
# On iteration 47, 0 knot(s) were detected with a time of 1.4421048164
# On iteration 48, 0 knot(s) were detected with a time of 1.393001318
# On iteration 49, 0 knot(s) were detected with a time of 1.4006593227
# Total program runtime: 87.00077581390002
